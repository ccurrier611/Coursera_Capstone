# %% [markdown]
# #  Applied Data Science Capstone Project Notebook

# %% [markdown]
# ## Week 1 Capstone Project

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %% [markdown]
# ## Week 3 Segmenting and Clustering

# %% [markdown]
# ### Part 1 Create the Data Frame

# %% [markdown]
# The next lines of code are my attempt at web scraping to get the postal code data from wikipedia.

# %%
#!pip install lxml
 
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", match='Borough')
len(df)
# Out:
# 1

# %%
t_df = df[0]
t_df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Dropping rows that do not have a borough assigned.

# %%
t_df.drop(t_df[t_df['Borough'] == 'Not assigned'].index, inplace = True) 
t_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Replacing neighbourhoods not assigned with the borough names.

# %%
t_df['Neighbourhood'] = np.where(t_df['Neighbourhood'] == 'Not assigned', t_df['Borough'], t_df['Neighbourhood'])
t_df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
t_df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Part 2 Get Geo Location Data

# %% [markdown]
# Merge two data bases so the lat and lng for each borough are listed.

# %%
t_df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
geo_df = pd.read_csv('http://cocl.us/Geospatial_data')
geo_df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
t_df2 = pd.merge(t_df, geo_df, on='Postal Code')
t_df2
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# Getting borough names to narrow search in next part of project.

# %%
t_df2.Borough.unique()
# Out:
# array(['North York', 'Downtown Toronto', 'Etobicoke', 'Scarborough',
#        'East York', 'York', 'East Toronto', 'West Toronto',
#        'Central Toronto', 'Mississauga'], dtype=object)

# %% [markdown]
# ### Part 3 Exploring the Boroughs of Toronto

# %% [markdown]
# Importing and Installing needed libraries to map and analyze data.

# %%
from geopy.geocoders import Nominatim
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
#! pip install folium
import folium

from IPython.display import Image
from IPython.core.display import HTML

from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, Canada'

geolocater = Nominatim(user_agent="tor_explorer")
location = geolocater.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical cooridinate of Toronto is {}, {}'.format(latitude, longitude))
# Out:
# The geographical cooridinate of Toronto is 43.6534817, -79.3839347

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lng, borough, neighbourhood in zip(t_df2['Latitude'], t_df2['Longitude'], t_df2['Borough'], t_df2['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bdf9db66d01044b6b41a216d773181e9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bdf9db66d01044b6b41a216d773181e9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bdf9db66d01044b6b41a216d773181e9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bdf9db66d01044b6b41a216d773181e9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Isolating the borough of Downtown Toronto.

# %%
toronto_data = t_df2[t_df2['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
toronto_data.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M5E  Downtown Toronto                                  Berczy Park
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.644771 -79.373306

# %%
address='Downtown Toronto'

geolocater = Nominatim(user_agent="dt_explorer")
location = geolocater.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical cooridinate of Downtown Toronto is {}, {}'.format(latitude, longitude))
# Out:
# The geographical cooridinate of Downtown Toronto is 43.6541737, -79.38081164513409

# %%
map_dttoronto = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dttoronto)
    
map_dttoronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4360e8c7fc804053b659fdbb7eedae00%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4360e8c7fc804053b659fdbb7eedae00%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4360e8c7fc804053b659fdbb7eedae00%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4360e8c7fc804053b659fdbb7eedae00%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6541737%2C%20-79.38081164513409%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Now I will use Foursquare to explore the neighbourhoods.

# %%
CLIENT_ID = 'H5KGSVX0LK3XUNBPMWSWTHP0Q0YSJJNSNAC2XHWGWH4KH25L'
CLIENT_SECRET = 'KC402O2PMBUX5TPRSMM3AB4Y2VQWEQWSRNP4XFINZMGBONTF'
VERSION = '20180605'
LIMIT = 100

toronto_data.loc[8, 'Neighbourhood']
# Out:
# 'Harbourfront East, Union Station, Toronto Islands'

# %%
neighbourhood_latitude = toronto_data.loc[8, 'Latitude']
neighbourhood_longitude = toronto_data.loc[8, 'Longitude']
neighbourhood_name = toronto_data.loc[8, 'Neighbourhood']

limit = 100

radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, neighbourhood_latitude, neighbourhood_longitude, radius, LIMIT)

url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '600ef8af512f380ec1adfeab'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Harbourfront',
#   'headerFullLocation': 'Harbourfront, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 151,
#   'suggestedBounds': {'ne': {'lat': 43.6453157045, 'lng': -79.37554568947675},
#    'sw': {'lat': 43.636315695499995, 'lng': -79.38795891052322}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfaa3494a67c928d08528cf',
#        'name': 'Harbourfront',
#        'location': {'lat': 43.639525632239106,
#         'lng': -79.38068838052389,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.639525632239106,
#           'lng': -79.38068838052389}],
#         'distance': 167,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4f2a25ac4b909258e854f55f',
#          'name': 'Neighborhood',
#          'pluralName': 'Neighborhoods',
#          'shortName': 'Neighborhood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfaa3494a67c928d08528cf-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b642db1f964a520b7a22ae3',
#        'name': 'Roundhouse Park',
#        'location': {'address': '255 Bremner Blvd.',
#         'crossStreet': 'at Lower Simcoe St.',
#         'lat': 43.64174513889102,
#         'lng': -79.38427882922346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64174513889102,
#           'lng': -79.38427882922346}],
#         'distance': 228,
#         'postalCode': 'M5V 3M9',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Bremner Blvd. (at Lower Simcoe St.)',
#          'Toronto ON M5V 3M9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b642db1f964a520b7a22ae3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a19437498eeea53fa58b54',
#        'name': 'BeaverTails',
#        'location': {'address': '145 Queen’s Quay W',
#         'crossStreet': 'York St',
#         'lat': 43.639736,
#         'lng': -79.380068,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.639736,
#           'lng': -79.380068}],
#         'distance': 181,
#         'postalCode': 'M5J 2H4',
#         'cc': 'CA',
#         'neighborhood': 'Harbourfront',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 Queen’s Quay W (York St)',
#          'Toronto ON M5J 2H4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a19437498eeea53fa58b54-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d07f8041657a35d19272ae7',
#        'name': 'Lake Ontario',
#        'location': {'lat': 43.63894493157648,
#         'lng': -79.37966465950012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63894493157648,
#           'lng': -79.37966465950012}],
#         'distance': 267,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d07f8041657a35d19272ae7-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a52094f620e3',
#        'name': 'Harbourfront Centre',
#        'location': {'address': '235 Queens Quay West',
#         'crossStreet': 'at Lower Simcoe St.',
#         'lat': 43.63855578926675,
#         'lng': -79.38319016270458,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63855578926675,
#           'lng': -79.38319016270458}],
#         'distance': 276,
#         'postalCode': 'M5J 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['235 Queens Quay West (at Lower Simcoe St.)',
#          'Toronto ON M5J 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37512083'}},
#       'referralId': 'e-0-4ad4c05ef964a52094f620e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdb8c1cc79cc928a77583e9',
#        'name': 'Maple Leaf Square',
#        'location': {'address': '15 York St.',
#         'crossStreet': 'Bremner Blvd.',
#         'lat': 43.64292522840183,
#         'lng': -79.38089182467687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64292522840183,
#           'lng': -79.38089182467687}],
#         'distance': 244,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 York St. (Bremner Blvd.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33431413'}},
#       'referralId': 'e-0-4bdb8c1cc79cc928a77583e9-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5346c98a498ed612110d0f60',
#        'name': 'iQ Food Co',
#        'location': {'address': '18 York Street',
#         'crossStreet': 'Bremner Ave',
#         'lat': 43.642851,
#         'lng': -79.382081,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.642851,
#           'lng': -79.382081}],
#         'distance': 228,
#         'postalCode': 'M5J 0B2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['18 York Street (Bremner Ave)',
#          'Toronto ON M5J 0B2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5346c98a498ed612110d0f60-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4caaabd8f47ea143763b8521',
#        'name': "Longo's Maple Leaf Square",
#        'location': {'address': '15 York St.',
#         'crossStreet': 'enter on Bremner',
#         'lat': 43.64251679604069,
#         'lng': -79.38139301653129,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64251679604069,
#           'lng': -79.38139301653129}],
#         'distance': 191,
#         'postalCode': 'M5J 0A3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 York St. (enter on Bremner)',
#          'Toronto ON M5J 0A3',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4caaabd8f47ea143763b8521-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be46c832468c92887c1fe42',
#        'name': 'Real Sports Apparel',
#        'location': {'address': '15 York St. Unit B',
#         'crossStreet': 'Maple Leaf Square',
#         'lat': 43.64285984835777,
#         'lng': -79.38018363195047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64285984835777,
#           'lng': -79.38018363195047}],
#         'distance': 260,
#         'postalCode': 'M5J',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 York St. Unit B (Maple Leaf Square)',
#          'Toronto ON M5J',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33431415'}},
#       'referralId': 'e-0-4be46c832468c92887c1fe42-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53357710498e20817350cfb4',
#        'name': 'Delta Hotels by Marriott Toronto',
#        'location': {'address': '75 Lower Simcoe Street',
#         'lat': 43.6428819,
#         'lng': -79.3839491,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6428819,
#           'lng': -79.3839491}],
#         'distance': 290,
#         'postalCode': 'M5J 3A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['75 Lower Simcoe Street',
#          'Toronto ON M5J 3A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53357710498e20817350cfb4-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7199ebf964a52048502de3',
#        'name': 'Natrel Pond/Rink',
#        'location': {'address': '235 Queens Quay W',
#         'crossStreet': 'Harbourfront Centre',
#         'lat': 43.6384313677662,
#         'lng': -79.38252754335107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6384313677662,
#           'lng': -79.38252754335107}],
#         'distance': 272,
#         'postalCode': 'M5J 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['235 Queens Quay W (Harbourfront Centre)',
#          'Toronto ON M5J 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d168941735',
#          'name': 'Skating Rink',
#          'pluralName': 'Skating Rinks',
#          'shortName': 'Skating Rink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skatingrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7199ebf964a52048502de3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a988a27dc9e105c88b184b',
#        'name': 'Aroma Espresso Bar',
#        'location': {'address': '137 Bremner Blvd',
#         'crossStreet': 'Lower Simcoe St',
#         'lat': 43.6423209103846,
#         'lng': -79.38374932648954,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6423209103846,
#           'lng': -79.38374932648954}],
#         'distance': 232,
#         'postalCode': 'M5J 3A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['137 Bremner Blvd (Lower Simcoe St)',
#          'Toronto ON M5J 3A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a988a27dc9e105c88b184b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e49413e81dc766f3e3d6312',
#        'name': 'Harbour Square Park',
#        'location': {'address': '25 Queens Quay West',
#         'lat': 43.63925269130776,
#         'lng': -79.37839547902978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63925269130776,
#           'lng': -79.37839547902978}],
#         'distance': 321,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['25 Queens Quay West', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e49413e81dc766f3e3d6312-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515779bee4b0a9d4c8c9380d',
#        'name': 'Ontario Square',
#        'location': {'lat': 43.63937829745867,
#         'lng': -79.38209598496967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63937829745867,
#           'lng': -79.38209598496967}],
#         'distance': 162,
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['Canada']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515779bee4b0a9d4c8c9380d-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb87a334c60a093c04a39ca',
#        'name': 'Le Germain Hotel',
#        'location': {'address': '75 Bremner Boulevard',
#         'crossStreet': 'York Street',
#         'lat': 43.64312502979691,
#         'lng': -79.38091770864038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64312502979691,
#           'lng': -79.38091770864038}],
#         'distance': 265,
#         'postalCode': 'M5J 0A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['75 Bremner Boulevard (York Street)',
#          'Toronto ON M5J 0A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb87a334c60a093c04a39ca-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5014414be4b05d9dc85cf8a1',
#        'name': 'Lick It Gelato',
#        'location': {'address': '250 Queens Quay W',
#         'lat': 43.63925633222479,
#         'lng': -79.38464951914256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63925633222479,
#           'lng': -79.38464951914256}],
#         'distance': 290,
#         'postalCode': 'M5J 2N2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['250 Queens Quay W',
#          'Toronto ON M5J 2N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5014414be4b05d9dc85cf8a1-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9fbdd77c096dcbfe43e1d1',
#        'name': 'e11even',
#        'location': {'address': '15 York St.',
#         'crossStreet': 'at Bremner Blvd.',
#         'lat': 43.64242558687748,
#         'lng': -79.38144094115985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64242558687748,
#           'lng': -79.38144094115985}],
#         'distance': 180,
#         'postalCode': 'M5J 0A3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 York St. (at Bremner Blvd.)',
#          'Toronto ON M5J 0A3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33864002'}},
#       'referralId': 'e-0-4c9fbdd77c096dcbfe43e1d1-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b9b9aa498e6f9349fd2125',
#        'name': 'Taverna Mercatto',
#        'location': {'address': '130 Bremner',
#         'lat': 43.64262514139939,
#         'lng': -79.38325673989138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64262514139939,
#           'lng': -79.38325673989138}],
#         'distance': 235,
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['130 Bremner', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54b9b9aa498e6f9349fd2125-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b55dfbff964a5200ef427e3',
#        'name': 'TELUS',
#        'location': {'address': '25 York St UNIT A7',
#         'lat': 43.64331243103257,
#         'lng': -79.38099939294844,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64331243103257,
#           'lng': -79.38099939294844}],
#         'distance': 284,
#         'postalCode': 'M5J 2V5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['25 York St UNIT A7',
#          'Toronto ON M5J 2V5',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b36',
#          'name': 'IT Services',
#          'pluralName': 'IT Services',
#          'shortName': 'IT Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b55dfbff964a5200ef427e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '562922be498e2c6aad0e6091',
#        'name': 'Evviva Restaurant',
#        'location': {'address': '25 Lower Simcoe St',
#         'crossStreet': 'Grand Trunk Cresc',
#         'lat': 43.64157991761808,
#         'lng': -79.38345644030795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64157991761808,
#           'lng': -79.38345644030795}],
#         'distance': 161,
#         'postalCode': 'M5J 3A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['25 Lower Simcoe St (Grand Trunk Cresc)',
#          'Toronto ON M5J 3A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-562922be498e2c6aad0e6091-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56cca056cd10f4e133df3253',
#        'name': 'Delta Toronto Club Lounge',
#        'location': {'address': '75 Lower Simcoe',
#         'lat': 43.64308454373067,
#         'lng': -79.38388489051405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64308454373067,
#           'lng': -79.38388489051405}],
#         'distance': 305,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['75 Lower Simcoe', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d133951735',
#          'name': 'Roof Deck',
#          'pluralName': 'Roof Decks',
#          'shortName': 'Roof Deck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56cca056cd10f4e133df3253-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56201ed4498e7f700c462170',
#        'name': 'Miku',
#        'location': {'address': '10 Bay St',
#         'crossStreet': 'at Queens Quay W',
#         'lat': 43.64137436,
#         'lng': -79.37753063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64137436,
#           'lng': -79.37753063}],
#         'distance': 345,
#         'postalCode': 'M5J 2R8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['10 Bay St (at Queens Quay W)',
#          'Toronto ON M5J 2R8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56201ed4498e7f700c462170-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b155081f964a520b4b023e3',
#        'name': 'Scotiabank Arena',
#        'location': {'address': '40 Bay St',
#         'lat': 43.64344617535107,
#         'lng': -79.37903988889991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64344617535107,
#           'lng': -79.37903988889991}],
#         'distance': 365,
#         'postalCode': 'M5J 2X2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 Bay St', 'Toronto ON M5J 2X2', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d18b941735',
#          'name': 'Basketball Stadium',
#          'pluralName': 'Basketball Stadiums',
#          'shortName': 'Basketball',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_basketball_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33431410'}},
#       'referralId': 'e-0-4b155081f964a520b4b023e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a520bff720e3',
#        'name': 'Fleck Dance Theater',
#        'location': {'address': '235 Queens Quay West',
#         'lat': 43.638300366812686,
#         'lng': -79.3804699399247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.638300366812686,
#           'lng': -79.3804699399247}],
#         'distance': 298,
#         'postalCode': 'M5J 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['235 Queens Quay West',
#          'Toronto ON M5J 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d134941735',
#          'name': 'Dance Studio',
#          'pluralName': 'Dance Studios',
#          'shortName': 'Dance Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c062f964a520bff720e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b60d5b9f964a52071fc29e3',
#        'name': 'Air Canada Club',
#        'location': {'address': 'Air Canada Centre',
#         'lat': 43.643224100030416,
#         'lng': -79.37915938219528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.643224100030416,
#           'lng': -79.37915938219528}],
#         'distance': 339,
#         'postalCode': 'M5J 2L2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Air Canada Centre',
#          'Toronto ON M5J 2L2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b60d5b9f964a52071fc29e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57768fb1498ec8fca5cc0594',
#        'name': 'Boxcar Social',
#        'location': {'address': '235 Queens Quay W',
#         'lat': 43.63831906511549,
#         'lng': -79.38246311921247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63831906511549,
#           'lng': -79.38246311921247}],
#         'distance': 283,
#         'postalCode': 'M5J 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['235 Queens Quay W',
#          'Toronto ON M5J 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57768fb1498ec8fca5cc0594-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55561f8a498e2e5c866ac4c9',
#        'name': 'Union Pearson Express',
#        'location': {'address': '61 Front St. W',
#         'lat': 43.64436200658875,
#         'lng': -79.38319927907953,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64436200658875,
#           'lng': -79.38319927907953}],
#         'distance': 411,
#         'postalCode': 'M5J 2Z8',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['61 Front St. W',
#          'Toronto ON M5J 2Z8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'shortName': 'Train Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55561f8a498e2e5c866ac4c9-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ff964a520edf620e3',
#        'name': 'The Power Plant',
#        'location': {'address': '231 Queens Quay West',
#         'lat': 43.63827200397285,
#         'lng': -79.38199390946676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63827200397285,
#           'lng': -79.38199390946676}],
#         'distance': 283,
#         'postalCode': 'M5J 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['231 Queens Quay West',
#          'Toronto ON M5J 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ff964a520edf620e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57b22076498efeeeb93cfc47',
#        'name': 'Sharetea',
#        'location': {'address': '109-89 Queens Quay W',
#         'lat': 43.640175967763966,
#         'lng': -79.37960567018246,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.640175967763966,
#           'lng': -79.37960567018246}],
#         'distance': 187,
#         'postalCode': 'M5J 2T5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['109-89 Queens Quay W',
#          'Toronto ON M5J 2T5',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57b22076498efeeeb93cfc47-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f05da6f0e61b14c28b2e05f',
#        'name': "Ripley's Aquarium of Canada",
#        'location': {'address': '288 Bremner Blvd',
#         'lat': 43.642104321965796,
#         'lng': -79.38625159146146,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.642104321965796,
#           'lng': -79.38625159146146}],
#         'distance': 389,
#         'postalCode': 'M5J 3A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['288 Bremner Blvd',
#          'Toronto ON M5J 3A6',
#          'Canada']},
#        'categories': [{'id': '4fceea171983d5d06c3e9823',
#          'name': 'Aquarium',
#          'pluralName': 'Aquariums',
#          'shortName': 'Aquarium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/aquarium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f05da6f0e61b14c28b2e05f-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a520cbf620e3',
#        'name': 'Steam Whistle Brewing',
#        'location': {'address': '255 Bremner Blvd.',
#         'crossStreet': 'btwn Rees St. & Simcoe St.',
#         'lat': 43.641751628677554,
#         'lng': -79.38708862583252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.641751628677554,
#           'lng': -79.38708862583252}],
#         'distance': 442,
#         'postalCode': 'M5V 3M9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Bremner Blvd. (btwn Rees St. & Simcoe St.)',
#          'Toronto ON M5V 3M9',
#          'Canada']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33864025'}},
#       'referralId': 'e-0-4ad4c05ef964a520cbf620e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c57636330d82d7f57d3d962',
#        'name': 'Toronto Railway Heritage Centre',
#        'location': {'address': 'Roundhouse Park',
#         'lat': 43.64130010529897,
#         'lng': -79.38588431405732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64130010529897,
#           'lng': -79.38588431405732}],
#         'distance': 337,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Roundhouse Park', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c57636330d82d7f57d3d962-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '545bef71498eddc2599b086a',
#        'name': 'SOCO Kitchen+Bar',
#        'location': {'address': '75 Lower Simcoe Street',
#         'crossStreet': 'Bremner',
#         'lat': 43.64303873929366,
#         'lng': -79.38380850724118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64303873929366,
#           'lng': -79.38380850724118}],
#         'distance': 297,
#         'postalCode': 'M5J 3A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['75 Lower Simcoe Street (Bremner)',
#          'Toronto ON M5J 3A6',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-545bef71498eddc2599b086a-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbcd229593fef3b77ab0256',
#        'name': 'Booster Juice',
#        'location': {'address': '25 York Street, Unit #A6',
#         'crossStreet': 'In Telus Tower',
#         'lat': 43.64322536,
#         'lng': -79.3812383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64322536,
#           'lng': -79.3812383}],
#         'distance': 271,
#         'postalCode': 'M5J 2V5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['25 York Street, Unit #A6 (In Telus Tower)',
#          'Toronto ON M5J 2V5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbcd229593fef3b77ab0256-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a52096f620e3',
#        'name': 'CN Tower',
#        'location': {'address': '301 Front St W',
#         'crossStreet': 'at John St',
#         'lat': 43.642277432828145,
#         'lng': -79.38705542070056,
#         'distance': 457,
#         'postalCode': 'M5V 2T6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['301 Front St W (at John St)',
#          'Toronto ON M5V 2T6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33864000'}},
#       'referralId': 'e-0-4ad4c05ef964a52096f620e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff45283e4b0aeae9d3ae866',
#        'name': 'Sky Pod',
#        'location': {'address': 'CN Tower',
#         'lat': 43.64256148814412,
#         'lng': -79.38703777833165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64256148814412,
#           'lng': -79.38703777833165}],
#         'distance': 468,
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['CN Tower', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff45283e4b0aeae9d3ae866-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a53c6b0b0405614996330c6',
#        'name': 'Mos Mos',
#        'location': {'address': '20 Bay street',
#         'crossStreet': 'harbour',
#         'lat': 43.64163954520267,
#         'lng': -79.3775517786762,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64163954520267,
#           'lng': -79.3775517786762}],
#         'distance': 350,
#         'postalCode': 'M5J',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['20 Bay street (harbour)',
#          'Toronto ON M5J',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a53c6b0b0405614996330c6-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5671984a498eb233dad6c790',
#        'name': 'Ray Bay',
#        'location': {'address': "Ripley's Aquarium Of Canada",
#         'lat': 43.642323,
#         'lng': -79.38593,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.642323,
#           'lng': -79.38593}],
#         'distance': 376,
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ["Ripley's Aquarium Of Canada", 'Canada']},
#        'categories': [{'id': '4fceea171983d5d06c3e9823',
#          'name': 'Aquarium',
#          'pluralName': 'Aquariums',
#          'shortName': 'Aquarium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/aquarium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5671984a498eb233dad6c790-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae33054f964a520759121e3',
#        'name': 'Pearl Harbourfront',
#        'location': {'address': '200-207 Queens Quay W.',
#         'lat': 43.63815654013541,
#         'lng': -79.38068763743328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63815654013541,
#           'lng': -79.38068763743328}],
#         'distance': 308,
#         'postalCode': 'M5J 1A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200-207 Queens Quay W.',
#          'Toronto ON M5J 1A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae33054f964a520759121e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c061f964a520adf720e3',
#        'name': 'Rogers Centre',
#        'location': {'address': '1 Blue Jays Way',
#         'crossStreet': 'at Front St',
#         'lat': 43.64175329733295,
#         'lng': -79.38714957057036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64175329733295,
#           'lng': -79.38714957057036}],
#         'distance': 447,
#         'postalCode': 'M5V 1J1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Blue Jays Way (at Front St)',
#          'Toronto ON M5V 1J1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d18c941735',
#          'name': 'Baseball Stadium',
#          'pluralName': 'Baseball Stadiums',
#          'shortName': 'Baseball',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_baseball_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c061f964a520adf720e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '567197e7498e8ca8c0fe5ea4',
#        'name': 'Dangerous Lagoon',
#        'location': {'address': "Ripley's Aquarium Of Canada",
#         'lat': 43.64233,
#         'lng': -79.385925,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64233,
#           'lng': -79.385925}],
#         'distance': 376,
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc1fe8bb492d13aa9bba660-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a52000f820e3',
#        'name': "Queen's Quay Terminal",
#        'location': {'address': "207 Queen's Quay West",
#         'crossStreet': 'York St.',
#         'lat': 43.63831769002353,
#         'lng': -79.38041263300326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63831769002353,
#           'lng': -79.38041263300326}],
#         'distance': 298,
#         'postalCode': 'M5J 1A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["207 Queen's Quay West (York St.)",
#          'Toronto ON M5J 1A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'shortName': 'Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33705340'}},
#       'referralId': 'e-0-4ad4c062f964a52000f820e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0f2414c3658815295727a5',
#        'name': 'The Danish Pastry House',
#        'location': {'address': '65 Front St W',
#         'crossStreet': 'York',
#         'lat': 43.64526188121351,
#         'lng': -79.38084966956498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64526188121351,
#           'lng': -79.38084966956498}],
#         'distance': 500,
#         'postalCode': 'M5X 4A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['65 Front St W (York)',
#          'Toronto ON M5X 4A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a0f2414c3658815295727a5-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05bf964a5209bf520e3',
#        'name': 'The Westin Harbour Castle, Toronto',
#        'location': {'address': '1 Harbour Square',
#         'crossStreet': 'at Bay St',
#         'lat': 43.64121139206991,
#         'lng': -79.37574863433838,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64121139206991,
#           'lng': -79.37574863433838}],
#         'distance': 485,
#         'postalCode': 'M5J 1A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Harbour Square (at Bay St)',
#          'Toronto ON M5J 1A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05bf964a5209bf520e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c927dd2418ea1cd576aa585',
#        'name': 'Starbucks',
#        'location': {'address': '123 Front St W',
#         'crossStreet': 'at University Ave.',
#         'lat': 43.64510181136508,
#         'lng': -79.38360972232998,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64510181136508,
#           'lng': -79.38360972232998}],
#         'distance': 500,
#         'postalCode': 'M5J 2M2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['123 Front St W (at University Ave.)',
#          'Toronto ON M5J 2M2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c927dd2418ea1cd576aa585-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac3763afebf311c5484e49f',
#        'name': 'Winners',
#        'location': {'address': '1 York St',
#         'crossStreet': 'Harbour St',
#         'lat': 43.64206291678669,
#         'lng': -79.37900143460836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64206291678669,
#           'lng': -79.37900143460836}],
#         'distance': 261,
#         'postalCode': 'M5J 3B2',
#         'cc': 'CA',
#         'neighborhood': 'Harbourfront',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 York St (Harbour St)',
#          'Toronto ON M5J 3B2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac3763afebf311c5484e49f-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56cf4d80498ebf41870d5317',
#        'name': 'Starbucks',
#        'location': {'address': '65 Front St West',
#         'crossStreet': 'York St',
#         'lat': 43.644580752794965,
#         'lng': -79.38167197782931,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.644580752794965,
#           'lng': -79.38167197782931}],
#         'distance': 419,
#         'postalCode': 'M5J 1E5',
#         'cc': 'CA',
#         'neighborhood': 'Financial District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['65 Front St West (York St)',
#          'Toronto ON M5J 1E5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56cf4d80498ebf41870d5317-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba3d8def964a520086638e3',
#        'name': 'Tim Hortons',
#        'location': {'address': '207 Queens Quay',
#         'crossStreet': "on Queen's Quay Terminal",
#         'lat': 43.63882773618699,
#         'lng': -79.38037276268005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63882773618699,
#           'lng': -79.38037276268005}],
#         'distance': 247,
#         'postalCode': 'M5J 1A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["207 Queens Quay (on Queen's Quay Terminal)",
#          'Toronto ON M5J 1A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba3d8def964a520086638e3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd71d33e4b0b5e7100bfde6',
#        'name': 'The Chartroom Bar & Lounge',
#        'location': {'address': '1 Harbor Square',
#         'lat': 43.640485908474695,
#         'lng': -79.37604353917551,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.640485908474695,
#           'lng': -79.37604353917551}],
#         'distance': 461,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Harbor Square', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd71d33e4b0b5e7100bfde6-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db81aaa43a1a75c1f6afa6b',
#        'name': 'Starbucks',
#        'location': {'address': 'The Westin Harbour Castle',
#         'crossStreet': '1 Harbour Sq',
#         'lat': 43.64099011203675,
#         'lng': -79.37626361846924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64099011203675,
#           'lng': -79.37626361846924}],
#         'distance': 442,
#         'postalCode': 'M5J 1A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['The Westin Harbour Castle (1 Harbour Sq)',
#          'Toronto ON M5J 1A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db81aaa43a1a75c1f6afa6b-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6c9b5ff964a52027462ce3',
#        'name': 'Piazza Manna',
#        'location': {'address': '10 Bay St.',
#         'crossStreet': 'at Water Park Place',
#         'lat': 43.641460067165184,
#         'lng': -79.37771914472566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.641460067165184,
#           'lng': -79.37771914472566}],
#         'distance': 332,
#         'postalCode': 'M5J 2R8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['10 Bay St. (at Water Park Place)',
#          'Toronto ON M5J 2R8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6c9b5ff964a52027462ce3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a0c566fc9e941199511d9f',
#        'name': 'Kellys Landing',
#        'location': {'address': '123 Front St W',
#         'lat': 43.645081624120245,
#         'lng': -79.38304962483915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.645081624120245,
#           'lng': -79.38304962483915}],
#         'distance': 486,
#         'postalCode': 'M5J 2M2',
#         'cc': 'CA',
#         'neighborhood': 'Downtown Toronto, Toronto, ON',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['123 Front St W',
#          'Toronto ON M5J 2M2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a0c566fc9e941199511d9f-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4447edb0fb71d219804281',
#        'name': 'RBC Royal Bank',
#        'location': {'address': '88 QUEENS QUAY W',
#         'crossStreet': 'York',
#         'lat': 43.6408925738686,
#         'lng': -79.37841340899467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6408925738686,
#           'lng': -79.37841340899467}],
#         'distance': 269,
#         'postalCode': 'M5J 0B8',
#         'cc': 'CA',
#         'neighborhood': 'Harbourfront',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['88 QUEENS QUAY W (York)',
#          'Toronto ON M5J 0B8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4447edb0fb71d219804281-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd490c87da9a35d926ae4b9',
#        'name': 'TD Canada Trust',
#        'location': {'address': '15 York St',
#         'crossStreet': 'at Bremner Blvd.',
#         'lat': 43.64219452552069,
#         'lng': -79.38084349036222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64219452552069,
#           'lng': -79.38084349036222}],
#         'distance': 170,
#         'postalCode': 'M5J 0A3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['15 York St (at Bremner Blvd.)',
#          'Toronto ON M5J 0A3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd490c87da9a35d926ae4b9-99'}]}]}}

# %%
items = results['response']['groups'][0]['items']
items[0:2]
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bfaa3494a67c928d08528cf',
#    'name': 'Harbourfront',
#    'location': {'lat': 43.639525632239106,
#     'lng': -79.38068838052389,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 43.639525632239106,
#       'lng': -79.38068838052389}],
#     'distance': 167,
#     'cc': 'CA',
#     'city': 'Toronto',
#     'state': 'ON',
#     'country': 'Canada',
#     'formattedAddress': ['Toronto ON', 'Canada']},
#    'categories': [{'id': '4f2a25ac4b909258e854f55f',
#      'name': 'Neighborhood',
#      'pluralName': 'Neighborhoods',
#      'shortName': 'Neighborhood',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bfaa3494a67c928d08528cf-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b642db1f964a520b7a22ae3',
#    'name': 'Roundhouse Park',
#    'location': {'address': '255 Bremner Blvd.',
#     'crossStreet': 'at Lower Simcoe St.',
#     'lat': 43.64174513889102,
#     'lng': -79.38427882922346,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 43.64174513889102,
#       'lng': -79.38427882922346}],
#     'distance': 228,
#     'postalCode': 'M5V 3M9',
#     'cc': 'CA',
#     'neighborhood': 'Entertainment District',
#     'city': 'Toronto',
#     'state': 'ON',
#     'country': 'Canada',
#     'formattedAddress': ['255 Bremner Blvd. (at Lower Simcoe St.)',
#      'Toronto ON M5V 3M9',
#      'Canada']},
#    'categories': [{'id': '4bf58dd8d48988d163941735',
#      'name': 'Park',
#      'pluralName': 'Parks',
#      'shortName': 'Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b642db1f964a520b7a22ae3-1'}]

# %%
df_dt = json_normalize(items)

filtered_columns = ['venue.name', 'venue.categories'] + [col for col in df_dt.columns if col.startswith('venue.location')] + ['venue.id']
dataframe_filtered = df_dt.loc[:, filtered_columns]


dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                                name  \
# 0                      Harbourfront
# 1                   Roundhouse Park
# 2                       BeaverTails
# 3                      Lake Ontario
# 4               Harbourfront Centre
# 5                 Maple Leaf Square
# 6                        iQ Food Co
# 7         Longo's Maple Leaf Square
# 8               Real Sports Apparel
# 9  Delta Hotels by Marriott Toronto
#
#                                           categories        lat        lng  \
# 0  [{'id': '4f2a25ac4b909258e854f55f', 'name': 'N...  43.639526 -79.380688
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  43.641745 -79.384279
# 2  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  43.639736 -79.380068
# 3  [{'id': '4bf58dd8d48988d161941735', 'name': 'L...  43.638945 -79.379665
# 4  [{'id': '4bf58dd8d48988d1f2931735', 'name': 'P...  43.638556 -79.383190
# 5  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...  43.642925 -79.380892
# 6  [{'id': '4bf58dd8d48988d1bd941735', 'name': 'S...  43.642851 -79.382081
# 7  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  43.642517 -79.381393
# 8  [{'id': '4bf58dd8d48988d1f2941735', 'name': 'S...  43.642860 -79.380184
# 9  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  43.642882 -79.383949
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.63952563223910...       167  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.64174513889102...       228  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.639736, 'lng':...       181  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.63894493157648...       267  CA  Toronto
# 4  [{'label': 'display', 'lat': 43.63855578926675...       276  CA  Toronto
# 5  [{'label': 'display', 'lat': 43.64292522840183...       244  CA  Toronto
# 6  [{'label': 'display', 'lat': 43.642851, 'lng':...       228  CA  Toronto
# 7  [{'label': 'display', 'lat': 43.64251679604069...       191  CA  Toronto
# 8  [{'label': 'display', 'lat': 43.64285984835777...       260  CA  Toronto
# 9  [{'label': 'display', 'lat': 43.6428819, 'lng'...       290  CA  Toronto
#
#   state country                                   formattedAddress  \
# 0    ON  Canada                               [Toronto ON, Canada]
# 1    ON  Canada  [255 Bremner Blvd. (at Lower Simcoe St.), Toro...
# 2    ON  Canada  [145 Queen’s Quay W (York St), Toronto ON M5J ...
# 3    ON  Canada                               [Toronto ON, Canada]
# 4    ON  Canada  [235 Queens Quay West (at Lower Simcoe St.), T...
# 5    ON  Canada  [15 York St. (Bremner Blvd.), Toronto ON, Canada]
# 6    ON  Canada  [18 York Street (Bremner Ave), Toronto ON M5J ...
# 7    ON  Canada  [15 York St. (enter on Bremner), Toronto ON M5...
# 8    ON  Canada  [15 York St. Unit B (Maple Leaf Square), Toron...
# 9    ON  Canada  [75 Lower Simcoe Street, Toronto ON M5J 3A6, C...
#
#                   address          crossStreet postalCode  \
# 0                     NaN                  NaN        NaN
# 1       255 Bremner Blvd.  at Lower Simcoe St.    M5V 3M9
# 2      145 Queen’s Quay W              York St    M5J 2H4
# 3                     NaN                  NaN        NaN
# 4    235 Queens Quay West  at Lower Simcoe St.    M5J 2G8
# 5             15 York St.        Bremner Blvd.        NaN
# 6          18 York Street          Bremner Ave    M5J 0B2
# 7             15 York St.     enter on Bremner    M5J 0A3
# 8      15 York St. Unit B    Maple Leaf Square        M5J
# 9  75 Lower Simcoe Street                  NaN    M5J 3A6
#
#              neighborhood                        id
# 0                     NaN  4bfaa3494a67c928d08528cf
# 1  Entertainment District  4b642db1f964a520b7a22ae3
# 2            Harbourfront  55a19437498eeea53fa58b54
# 3                     NaN  4d07f8041657a35d19272ae7
# 4                     NaN  4ad4c05ef964a52094f620e3
# 5                     NaN  4bdb8c1cc79cc928a77583e9
# 6                     NaN  5346c98a498ed612110d0f60
# 7                     NaN  4caaabd8f47ea143763b8521
# 8                     NaN  4be46c832468c92887c1fe42
# 9                     NaN  53357710498e20817350cfb4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15)

folium.CircleMarker(
    [latitude, longitude],
    radius = 10,
    popup = 'Downtown Toronto',
    fill = True,
    color = 'yellow',
    fill_color = 'yellow',
    fill_opacity = 0.6,
    ).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        fill = True,
        color = 'blue',
        fill_color = 'blue',
        fill_opacity = 0.6,
        parse_html=False).add_to(venues_map)
    
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_693b8e88c7e24872b33146fa5c6337a1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_693b8e88c7e24872b33146fa5c6337a1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_693b8e88c7e24872b33146fa5c6337a1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_693b8e88c7e24872b33146fa5c6337a1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6541737%2C%20-79.38081164513409%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Map with all places located in the neighbourhoods of Harbourfront East, Union Station, Toronto Islands.
